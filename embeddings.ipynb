# %%
import os
from openai import OpenAI
client = OpenAI(api_key="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")

# %%
entries = [
    "USA 25000 CSE Top 10",
    "USA 40000 Law Top 10",
    "China 30000 Mathematics Top 100",
    "Germany 35000 Science Top 50",
    "USA 35000 CSE Top 10",
    "USA 10000 CSE Top 10"
]


embeddings  = []
for entry in entries:
    embd = client.embeddings.create(
    model="text-embedding-3-small",
    input=entry,
    dimensions=128,
    encoding_format="float"
    )
    print(embd.data[0].embedding)
    embeddings.append(embd.data[0].embedding)
# Out:
# [0.06333797, -0.0038128905, 0.12074065, 0.018484171, -0.08305159, 0.033703938, -0.058716923, 0.100136735, 0.07020594, -0.05095866, 0.12481056, -0.11073545, -0.12548888, -0.033809926, 0.21112655, 0.09191212, -6.334393e-05, -0.014997193, -0.0829244, -0.0029888398, -0.0050423425, -0.0076575773, -0.01766807, 0.0788121, 0.18382424, 0.027556678, -0.07444543, -0.1270151, 0.033703938, 0.042034533, 0.11489015, -0.11082024, -0.033470765, -0.16618797, -0.099288836, -0.06583927, 0.11260083, -0.033619147, -0.029231276, 0.07597164, 0.09360792, -0.09301439, 0.10598723, -0.055876467, 0.117688216, -0.074063875, 0.016163053, -0.21383983, 0.05566449, 0.10378269, -0.027662667, -0.014371868, 0.03669278, 0.11667074, -0.00921029, -0.034255072, 0.015993472, 0.10929403, 0.12769341, -0.11455099, 0.03020636, -0.20943075, 0.10327395, -0.049135678, 0.07584446, -0.05634281, 0.0032750054, 0.09666035, 0.06024314, 0.094455816, -0.15626757, 0.07932084, 0.054053485, 0.067492664, 0.0655849, -0.055537306, 0.03054552, -0
# ...
